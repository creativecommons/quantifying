# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
DATA_WRITE_FILE = "./data_google.txt"
google_cse_df = pd.read_csv(DATA_WRITE_FILE).iloc[1:, :-1].set_index("LICENSE TYPE")
google_cse_df.head(5)
# Out:
#                         No Priori  Australia  Brazil  Canada  Egypt  Germany  \
# LICENSE TYPE
# licenses/GPL/2.0/           66500         88     307      72      2     4010
# licenses/by-nc-nd/2.0/   19000000      11500    4150    5530    262    57300
# licenses/by-nc-nd/2.5/   26800000      17800    4680   16500    316    53800
# licenses/by-nc-nd/3.0/   29400000      23300   15500    7270    901    71600
# licenses/by-nc-nd/4.0/   75200000      28200   33400   22000    683   185000
#
#                         India  Japan  Spain  United Kingdom  United States  \
# LICENSE TYPE
# licenses/GPL/2.0/          23    106    969            1010          37200
# licenses/by-nc-nd/2.0/   3530   9180  14000           64300       10100000
# licenses/by-nc-nd/2.5/   4700  10300  16100           70300       14900000
# licenses/by-nc-nd/3.0/   4510  25400  22900           65800       14200000
# licenses/by-nc-nd/4.0/  15700  54600  39700          189000       50300000
#
#                         Arabic  Chinese (Simplified)  Chinese (Traditional)  \
# LICENSE TYPE
# licenses/GPL/2.0/          758                   429                    139
# licenses/by-nc-nd/2.0/    1370                  3890                    384
# licenses/by-nc-nd/2.5/     527                  3110                    497
# licenses/by-nc-nd/3.0/    1650                  5920                   1140
# licenses/by-nc-nd/4.0/    2530                 15600                   6100
#
#                          English  French  Indonesian  Portuguese  Spanish
# LICENSE TYPE
# licenses/GPL/2.0/          51500    2370         127        1410     3510
# licenses/by-nc-nd/2.0/  22400000  105000        3410       22100    68500
# licenses/by-nc-nd/2.5/  26400000   55600        1430       16400   166000
# licenses/by-nc-nd/3.0/  23500000  180000        3540      141000   148000
# licenses/by-nc-nd/4.0/  77900000  286000       20300       95800   252000

# %%
license_cat = pd.Series(google_cse_df.index).str.extract(
    r"(.+)/.+/",
    expand = False
).fillna("all")
license_cat.index = google_cse_df.index
license_ver = pd.Series(google_cse_df.index).str.extract(
    r"/(\d\.\d)/",
    expand = False
)
license_ver.index = google_cse_df.index
license_df = pd.DataFrame(
    index = google_cse_df.index,
    data = {"LICENSE CATEGORY": license_cat, "LICENSE VERSION": license_ver}
)
license_df.head(5)
# Out:
#                          LICENSE CATEGORY LICENSE VERSION
# LICENSE TYPE
# licenses/GPL/2.0/            licenses/GPL             2.0
# licenses/by-nc-nd/2.0/  licenses/by-nc-nd             2.0
# licenses/by-nc-nd/2.5/  licenses/by-nc-nd             2.5
# licenses/by-nc-nd/3.0/  licenses/by-nc-nd             3.0
# licenses/by-nc-nd/4.0/  licenses/by-nc-nd             4.0

# %%
google_cse_lic_mapped = google_cse_df.merge(license_df, left_index = True, right_index = True)
google_cse_lic_mapped
# Out:
#                          No Priori  Australia  Brazil  Canada  Egypt  Germany  \
# LICENSE TYPE
# licenses/GPL/2.0/            66500         88     307      72      2     4010
# licenses/by-nc-nd/2.0/    19000000      11500    4150    5530    262    57300
# licenses/by-nc-nd/2.5/    26800000      17800    4680   16500    316    53800
# licenses/by-nc-nd/3.0/    29400000      23300   15500    7270    901    71600
# licenses/by-nc-nd/4.0/    75200000      28200   33400   22000    683   185000
# licenses/by-nc-sa/1.0/     4240000       7100    3760    2290     84    29400
# licenses/by-nc-sa/2.0/     2570000       6090    2680    2840    105    31200
# licenses/by-nc-sa/2.5/     8120000       8730    3390    7210    140    26800
# licenses/by-nc-sa/3.0/     6060000      10200    6040    3730    477    48000
# licenses/by-nc-sa/4.0/    32200000      11800    8050    6750    438    57800
# licenses/by-nc/2.0/       18600000       9370    4030    5330    343    63700
# licenses/by-nc/2.5/       29100000      16100    7350   17800    227    64400
# licenses/by-nc/3.0/       22700000      19000   59900    7220    686    87600
# licenses/by-nc/4.0/       78200000      29700  125000   19800    837   159000
# licenses/by-nd-nc/1.0/    25400000      12400    4100    4720    119    61500
# licenses/by-nd/2.0/       72700000      36100    9600   12600   1270   254000
# licenses/by-nd/2.5/       71000000      59800   10100   22500    659   177000
# licenses/by-nd/3.0/       76200000      67000   30400   16600   7080   267000
# licenses/by-nd/4.0/      215000000     109000   64100   40800  10900  1580000
# licenses/by-sa/2.0/       31000000      15400    5670    7140    549   250000
# licenses/by-sa/2.5/       32300000      31300    5260    9320    501    68600
# licenses/by-sa/3.0/       46800000      23300   11400    9130   2920   518000
# licenses/by-sa/4.0/       97300000      33300   17200   15100   1840   890000
# licenses/by/1.0/          73000000      32900   10800   12000    637   223000
# licenses/by/2.0/          74900000      30800   12500   13300   1480   381000
# licenses/by/2.5/          68300000      55000   10500   20300   1040   173000
# licenses/by/3.0/          77100000      56800   65000   16200   8840   992000
# licenses/by/4.0/         221000000      99900  164000   41100  14700  4010000
# licenses/sampling+/1.0/   52600000      20800    4600    8310    157   171000
# publicdomain/mark/1.0/    19200000       3350     830    2490      4    50100
# publicdomain/zero/1.0/    39400000      12800    2120    5810      5   141000
# licenses/by-nc-nd/2.1/    24100000      17500    4900    5260    334    67400
# licenses/by-nc-sa/2.1/     7910000      10300    2870    3150    147    27900
# licenses/by-nc/2.1/       26300000      14500    4890    4550    212    59300
# licenses/by-nd/2.1/       66300000      48800   10300    8430    740   199000
# licenses/by-sa/2.1/       37500000      22300    6350    5030    261    71900
# licenses/by/2.1/          62800000      40600    8780    8780    548   146000
#
#                          India  Japan  Spain  United Kingdom  ...  Arabic  \
# LICENSE TYPE                                                  ...
# licenses/GPL/2.0/           23    106    969            1010  ...     758
# licenses/by-nc-nd/2.0/    3530   9180  14000           64300  ...    1370
# licenses/by-nc-nd/2.5/    4700  10300  16100           70300  ...     527
# licenses/by-nc-nd/3.0/    4510  25400  22900           65800  ...    1650
# licenses/by-nc-nd/4.0/   15700  54600  39700          189000  ...    2530
# licenses/by-nc-sa/1.0/    1080   3120   6070           24300  ...     284
# licenses/by-nc-sa/2.0/    1550   3310   8510           26600  ...     394
# licenses/by-nc-sa/2.5/    1910   2970   8610           36100  ...     211
# licenses/by-nc-sa/3.0/    2340   3820   9900           35500  ...    1470
# licenses/by-nc-sa/4.0/    4760  14200  16200           60300  ...     700
# licenses/by-nc/2.0/       2920  10700  14900           63600  ...    1340
# licenses/by-nc/2.5/       4830  12000  15600           83500  ...     498
# licenses/by-nc/3.0/       4310  24400  21000           65800  ...    2320
# licenses/by-nc/4.0/      15000  49600  38900          174000  ...    2340
# licenses/by-nd-nc/1.0/    2770  12100  11800           57500  ...     604
# licenses/by-nd/2.0/      15300  16100  32800          155000  ...   10100
# licenses/by-nd/2.5/      10900  17500  22400          155000  ...    5730
# licenses/by-nd/3.0/      17900  38900  38200          157000  ...   25300
# licenses/by-nd/4.0/      46800  95100  80900          563000  ...   21300
# licenses/by-sa/2.0/       5150   6270  16400           58300  ...    5520
# licenses/by-sa/2.5/       4030   4530  13900           63800  ...    4000
# licenses/by-sa/3.0/      10800  10800  22500           59500  ...   20100
# licenses/by-sa/4.0/      12100  21800  34700          126000  ...   13700
# licenses/by/1.0/          7380  16400  16700          140000  ...    5540
# licenses/by/2.0/         14100  21600  34200          141000  ...    7820
# licenses/by/2.5/         10800  15600  21400          135000  ...    6940
# licenses/by/3.0/         19000  39300  44500          144000  ...   32700
# licenses/by/4.0/         46400  90900  75800          505000  ...   24400
# licenses/sampling+/1.0/   4480   8590   8870          101000  ...     306
# publicdomain/mark/1.0/     266   5820   2280           26000  ...    5030
# publicdomain/zero/1.0/    1990   5830   2860           49800  ...    6240
# licenses/by-nc-nd/2.1/    1800  16700  15700           64000  ...     436
# licenses/by-nc-sa/2.1/    1030   6230  10500           32600  ...     297
# licenses/by-nc/2.1/       2160  13700  14600           73700  ...     686
# licenses/by-nd/2.1/      10100  20900  26500          147000  ...    3460
# licenses/by-sa/2.1/       3880  10000  14900           64400  ...    1350
# licenses/by/2.1/          7160  28700  25900          152000  ...    5240
#
#                          Chinese (Simplified)  Chinese (Traditional)  \
# LICENSE TYPE
# licenses/GPL/2.0/                         429                    139
# licenses/by-nc-nd/2.0/                   3890                    384
# licenses/by-nc-nd/2.5/                   3110                    497
# licenses/by-nc-nd/3.0/                   5920                   1140
# licenses/by-nc-nd/4.0/                  15600                   6100
# licenses/by-nc-sa/1.0/                   3750                     91
# licenses/by-nc-sa/2.0/                   2200                    248
# licenses/by-nc-sa/2.5/                   1400                    136
# licenses/by-nc-sa/3.0/                   4050                    539
# licenses/by-nc-sa/4.0/                   5630                    502
# licenses/by-nc/2.0/                      3930                    749
# licenses/by-nc/2.5/                      3690                   1130
# licenses/by-nc/3.0/                      5680                   1540
# licenses/by-nc/4.0/                     15300                   6590
# licenses/by-nd-nc/1.0/                   6380                    330
# licenses/by-nd/2.0/                     12300                   7580
# licenses/by-nd/2.5/                     13200                   5330
# licenses/by-nd/3.0/                    112000                  21700
# licenses/by-nd/4.0/                     54800                  33500
# licenses/by-sa/2.0/                      7920                   3600
# licenses/by-sa/2.5/                      6670                   3420
# licenses/by-sa/3.0/                     82700                  15500
# licenses/by-sa/4.0/                     28200                  15900
# licenses/by/1.0/                        16400                   4050
# licenses/by/2.0/                        14600                   8190
# licenses/by/2.5/                        12500                   5480
# licenses/by/3.0/                       109000                  27900
# licenses/by/4.0/                        67000                  43300
# licenses/sampling+/1.0/                  2460                     53
# publicdomain/mark/1.0/                  10700                   4910
# publicdomain/zero/1.0/                  10300                   6010
# licenses/by-nc-nd/2.1/                   6850                    645
# licenses/by-nc-sa/2.1/                   2900                    162
# licenses/by-nc/2.1/                      6640                    588
# licenses/by-nd/2.1/                     16000                   3230
# licenses/by-sa/2.1/                      6210                    760
# licenses/by/2.1/                        19000                   2880
#
#                            English   French  Indonesian  Portuguese   Spanish  \
# LICENSE TYPE
# licenses/GPL/2.0/            51500     2370         127        1410      3510
# licenses/by-nc-nd/2.0/    22400000   105000        3410       22100     68500
# licenses/by-nc-nd/2.5/    26400000    55600        1430       16400    166000
# licenses/by-nc-nd/3.0/    23500000   180000        3540      141000    148000
# licenses/by-nc-nd/4.0/    77900000   286000       20300       95800    252000
# licenses/by-nc-sa/1.0/     3880000    53800        1880       15200     13500
# licenses/by-nc-sa/2.0/     1350000    89300        1930       23900     37600
# licenses/by-nc-sa/2.5/     6810000    50700         668       16500    105000
# licenses/by-nc-sa/3.0/     3550000   155000        1610      135000    128000
# licenses/by-nc-sa/4.0/    29000000   260000       11200       82800    206000
# licenses/by-nc/2.0/       18200000    98200        5800       28600     59300
# licenses/by-nc/2.5/       29300000    51900        1420       18700    206000
# licenses/by-nc/3.0/       20800000   171000        2790      105000    422000
# licenses/by-nc/4.0/       70800000   292000       23400      195000    320000
# licenses/by-nd-nc/1.0/    23400000    42900        3570       12700     21700
# licenses/by-nd/2.0/       70300000    80300       21700       54500    253000
# licenses/by-nd/2.5/       66000000    58600        9330       29800    262000
# licenses/by-nd/3.0/       75000000   152000       56700      344000    782000
# licenses/by-nd/4.0/      227000000   275000      106000      220000    689000
# licenses/by-sa/2.0/       29000000   143000       13000       61700    184000
# licenses/by-sa/2.5/       29500000    83100        3700       32400    208000
# licenses/by-sa/3.0/       40000000   230000       28600      369000   1710000
# licenses/by-sa/4.0/       90500000   335000       46600      177000   1650000
# licenses/by/1.0/          74800000    94000       11500       29400    133000
# licenses/by/2.0/          69100000   155000       30100      105000    313000
# licenses/by/2.5/          63400000    94000        8810       37700    308000
# licenses/by/3.0/          68900000  4570000       64500      660000  10800000
# licenses/by/4.0/         215000000   399000      109000      339000   4160000
# licenses/sampling+/1.0/   56600000     6920        2160        4980     12900
# publicdomain/mark/1.0/    16300000    78800        3140       26900     87000
# publicdomain/zero/1.0/    42300000    63300        4880       23500     84200
# licenses/by-nc-nd/2.1/    24100000    47300        1970       16900     41700
# licenses/by-nc-sa/2.1/     6970000    38400        1000       16500     34500
# licenses/by-nc/2.1/       25800000    43500        1650       19100     50700
# licenses/by-nd/2.1/       71000000    43800        6830       26500    103000
# licenses/by-sa/2.1/       32500000    42200        3530       22900     56200
# licenses/by/2.1/          64200000    47400        8560       26500     94100
#
#                            LICENSE CATEGORY LICENSE VERSION
# LICENSE TYPE
# licenses/GPL/2.0/              licenses/GPL             2.0
# licenses/by-nc-nd/2.0/    licenses/by-nc-nd             2.0
# licenses/by-nc-nd/2.5/    licenses/by-nc-nd             2.5
# licenses/by-nc-nd/3.0/    licenses/by-nc-nd             3.0
# licenses/by-nc-nd/4.0/    licenses/by-nc-nd             4.0
# licenses/by-nc-sa/1.0/    licenses/by-nc-sa             1.0
# licenses/by-nc-sa/2.0/    licenses/by-nc-sa             2.0
# licenses/by-nc-sa/2.5/    licenses/by-nc-sa             2.5
# licenses/by-nc-sa/3.0/    licenses/by-nc-sa             3.0
# licenses/by-nc-sa/4.0/    licenses/by-nc-sa             4.0
# licenses/by-nc/2.0/          licenses/by-nc             2.0
# licenses/by-nc/2.5/          licenses/by-nc             2.5
# licenses/by-nc/3.0/          licenses/by-nc             3.0
# licenses/by-nc/4.0/          licenses/by-nc             4.0
# licenses/by-nd-nc/1.0/    licenses/by-nd-nc             1.0
# licenses/by-nd/2.0/          licenses/by-nd             2.0
# licenses/by-nd/2.5/          licenses/by-nd             2.5
# licenses/by-nd/3.0/          licenses/by-nd             3.0
# licenses/by-nd/4.0/          licenses/by-nd             4.0
# licenses/by-sa/2.0/          licenses/by-sa             2.0
# licenses/by-sa/2.5/          licenses/by-sa             2.5
# licenses/by-sa/3.0/          licenses/by-sa             3.0
# licenses/by-sa/4.0/          licenses/by-sa             4.0
# licenses/by/1.0/                licenses/by             1.0
# licenses/by/2.0/                licenses/by             2.0
# licenses/by/2.5/                licenses/by             2.5
# licenses/by/3.0/                licenses/by             3.0
# licenses/by/4.0/                licenses/by             4.0
# licenses/sampling+/1.0/  licenses/sampling+             1.0
# publicdomain/mark/1.0/    publicdomain/mark             1.0
# publicdomain/zero/1.0/    publicdomain/zero             1.0
# licenses/by-nc-nd/2.1/    licenses/by-nc-nd             2.1
# licenses/by-nc-sa/2.1/    licenses/by-nc-sa             2.1
# licenses/by-nc/2.1/          licenses/by-nc             2.1
# licenses/by-nd/2.1/          licenses/by-nd             2.1
# licenses/by-sa/2.1/          licenses/by-sa             2.1
# licenses/by/2.1/                licenses/by             2.1
#
# [37 rows x 21 columns]

# %%
google_cse_lic_type_sum = google_cse_lic_mapped.groupby("LICENSE CATEGORY").agg(np.sum)
google_cse_lic_type_sum.loc['Total'] = google_cse_lic_type_sum.sum()
google_cse_lic_type_sum
# Out:
#                      No Priori  Australia  Brazil  Canada  Egypt   Germany  \
# LICENSE CATEGORY
# licenses/GPL             66500         88     307      72      2      4010
# licenses/by          577100000     316000  271580  111680  27245   5925000
# licenses/by-nc       174900000      88670  201170   54700   2305    434000
# licenses/by-nc-nd    174500000      98300   62630   56560   2496    435100
# licenses/by-nc-sa     61100000      54220   26790   25970   1391    221100
# licenses/by-nd       501200000     320700  124500  100930  20649   2477000
# licenses/by-nd-nc     25400000      12400    4100    4720    119     61500
# licenses/by-sa       244900000     125600   45880   45720   6071   1798500
# licenses/sampling+    52600000      20800    4600    8310    157    171000
# publicdomain/mark     19200000       3350     830    2490      4     50100
# publicdomain/zero     39400000      12800    2120    5810      5    141000
# Total               1870366500    1052928  744507  416962  60444  11718310
#
#                      India   Japan   Spain  United Kingdom  United States  \
# LICENSE CATEGORY
# licenses/GPL            23     106     969            1010          37200
# licenses/by         104840  212500  218500         1217000      471900000
# licenses/by-nc       29220  110400  105000          460600      104890000
# licenses/by-nc-nd    30240  116180  108400          453400      104700000
# licenses/by-nc-sa    12670   33650   59790          215400       19767000
# licenses/by-nd      101000  188500  200800         1177000      398600000
# licenses/by-nd-nc     2770   12100   11800           57500       17300000
# licenses/by-sa       35960   53400  102400          372000      189500000
# licenses/sampling+    4480    8590    8870          101000       45200000
# publicdomain/mark      266    5820    2280           26000       17000000
# publicdomain/zero     1990    5830    2860           49800       35100000
# Total               323459  747076  821669         4130710     1403994200
#
#                     Arabic  Chinese (Simplified)  Chinese (Traditional)  \
# LICENSE CATEGORY
# licenses/GPL           758                   429                    139
# licenses/by          82640                238500                  91800
# licenses/by-nc        7184                 35240                  10597
# licenses/by-nc-nd     6513                 35370                   8766
# licenses/by-nc-sa     3356                 19930                   1678
# licenses/by-nd       65890                208300                  71340
# licenses/by-nd-nc      604                  6380                    330
# licenses/by-sa       44670                131700                  39180
# licenses/sampling+     306                  2460                     53
# publicdomain/mark     5030                 10700                   4910
# publicdomain/zero     6240                 10300                   6010
# Total               223191                699309                 234803
#
#                        English   French  Indonesian  Portuguese   Spanish
# LICENSE CATEGORY
# licenses/GPL             51500     2370         127        1410      3510
# licenses/by          555400000  5359400      232470     1197600  15808100
# licenses/by-nc       164900000   656600       35060      366400   1058000
# licenses/by-nc-nd    174300000   673900       30650      292200    676200
# licenses/by-nc-sa     51560000   647200       18288      289900    524600
# licenses/by-nd       509300000   609700      200560      674800   2089000
# licenses/by-nd-nc     23400000    42900        3570       12700     21700
# licenses/by-sa       221500000   833300       95430      663000   3808200
# licenses/sampling+    56600000     6920        2160        4980     12900
# publicdomain/mark     16300000    78800        3140       26900     87000
# publicdomain/zero     42300000    63300        4880       23500     84200
# Total               1815611500  8974390      626335     3553390  24173410

# %%
google_cse_totals_by_cl = pd.Series(data = google_cse_lic_type_sum.iloc[-1, 1:-1], index = google_cse_lic_type_sum.columns[1:-1])

plt.xticks(
    np.arange(
        0, max(np.log10(google_cse_totals_by_cl)) + 1
    )
)
sns.barplot(x = np.log10(google_cse_totals_by_cl), y = google_cse_totals_by_cl.index)
plt.xlabel("Total Number of Creative Common Works (log10)")
plt.title("Count of Creative Commons Attributed Webpages on Google,\n by Country and Language (2022, Sept.)")
# Out:
# Text(0.5, 1.0, 'Count of Creative Commons Attributed Webpages on Google,\n by Country and Language (2022, Sept.)')

# %%
google_cse_totals_by_lic = pd.Series(data = google_cse_df.sum(axis = 1), index = google_cse_df.index)
plt.figure(figsize=(10, 10), dpi=80)
plt.xticks(
    np.arange(
        0, max(np.log10(google_cse_totals_by_lic)) + 1
    )
)
sns.barplot(x = np.log10(google_cse_totals_by_lic), y = google_cse_totals_by_lic.index)
plt.xlabel("Total Number of Creative Common Works (log10)")
plt.title("Count of Creative Commons Attributed Webpages on Google,\n by License Type and Version (2022, Sept.)")
# Out:
# Text(0.5, 1.0, 'Count of Creative Commons Attributed Webpages on Google,\n by License Type and Version (2022, Sept.)')

# %%
lic_cat_no_total = google_cse_lic_type_sum.drop("Total")
google_cse_totals_lic_cat = pd.Series(data = lic_cat_no_total.sum(axis = 1), index = lic_cat_no_total.index)
plt.figure(figsize=(10, 10), dpi=80)
plt.xticks(
    np.arange(
        0, max(np.log10(google_cse_totals_lic_cat)) + 1
    )
)
sns.barplot(x = np.log10(google_cse_totals_lic_cat), y = google_cse_totals_lic_cat.index)
plt.xlabel("Total Number of Creative Common Works (log10)")
plt.title("Count of Creative Commons Attributed Webpages on Google,\n by License Category (2022, Sept.)")
# Out:
# Text(0.5, 1.0, 'Count of Creative Commons Attributed Webpages on Google,\n by License Category (2022, Sept.)')

# %%
google_cse_lic_ver_sum = google_cse_lic_mapped.groupby("LICENSE VERSION").agg(np.sum)
google_cse_lic_ver_sum.loc['Total'] = google_cse_lic_ver_sum.sum()
google_cse_lic_ver_sum
# Out:
#                   No Priori  Australia  Brazil  Canada  Egypt   Germany  \
# LICENSE VERSION
# 1.0               213840000      89350   26210   35620   1006    676000
# 2.0               218836500     109348   38937   46812   4011   1041210
# 2.1               224910000     154000   38090   35200   2242    571500
# 2.5               235620000     188730   41280   93630   2883    563600
# 3.0               258260000     199600  188240   60150  20904   1984200
# 4.0               718900000     311900  411750  145550  29398   6881800
# Total            1870366500    1052928  744507  416962  60444  11718310
#
#                   India   Japan   Spain  United Kingdom  United States  \
# LICENSE VERSION
# 1.0               17966   51860   48580          398600      176807000
# 2.0               42573   67266  121779          509810      154594200
# 2.1               26130   96230  108100          533700      138911000
# 2.5               37170   62900   98010          543700      166924000
# 3.0               58860  142620  159000          527600      205358000
# 4.0              140760  326200  286200         1617300      561400000
# Total            323459  747076  821669         4130710     1403994200
#
#                  Arabic  Chinese (Simplified)  Chinese (Traditional)  \
# LICENSE VERSION
# 1.0               18004                 49990                  15444
# 2.0               27302                 45269                  20890
# 2.1               11469                 57600                   8265
# 2.5               17906                 40570                  15993
# 3.0               83540                319350                  68319
# 4.0               64970                186530                 105892
# Total            223191                699309                 234803
#
#                     English   French  Indonesian  Portuguese   Spanish
# LICENSE VERSION
# 1.0               217280000   339720       27130      112680    352300
# 2.0               210401500   673170       76067      297210    918910
# 2.1               224570000   262600       23540      128400    380200
# 2.5               221410000   393900       25358      151500   1255000
# 3.0               231750000  5458000      157740     1754000  13990000
# 4.0               710200000  1847000      316500     1109600   7277000
# Total            1815611500  8974390      626335     3553390  24173410

# %%
lic_ver_no_total = google_cse_lic_ver_sum.drop("Total")
google_cse_totals_lic_ver = pd.Series(data = lic_ver_no_total.sum(axis = 1), index = lic_ver_no_total.index)
plt.figure(figsize=(10, 3.5), dpi=80)
plt.xticks(
    np.arange(
        0, max(google_cse_totals_lic_ver / (10 ** 8)) + 1
    )
)
sns.barplot(x = google_cse_totals_lic_ver / (10 ** 8), y = google_cse_totals_lic_ver.index)
plt.xlabel("Total Number of Creative Common Works (log10)")
plt.title("Count of Creative Commons Attributed Webpages on Google,\n by License Category (2022, Sept.)")
# Out:
# Text(0.5, 1.0, 'Count of Creative Commons Attributed Webpages on Google,\n by License Category (2022, Sept.)')
